# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import random
from sklearn.model_selection import train_test_split
import tensorflow.keras.datasets.cifar10
import keras
from keras_preprocessing.image import ImageDataGenerator
from functools import partial

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Bronnen:
#
# - hands on machine learning with scikit-learn keras and tensorflow: Chapter 14 - Deep Computer Vision Using Convolutional Neural Networks
# - MIT 6.S191 (2020): Convolutional Neural Networks (https://www.youtube.com/watch?v=iaSUYvmCekI)
# - https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/

# %% [markdown]
# # Data Preparation

# %%
# zonder dit krijg ik een error bij het downloaden van de dataset
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
data = keras.datasets.cifar10.load_data()

# %%
label_dict = {0:'airplane', 1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %%
(X_train, y_train), (X_test, y_test) = data

# %%
# one-hot encode the targets
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# # Data Augmentation
# ![data_augmentation.png](attachment:data_augmentation.png)
# Positief effect op accuracy:
#
#     - horizontal flip
#     - brightness
#
# Negatief of geen effect op accuracy:
#
#     - height/width shift
#     - rotation
#     - zoom

# %%
datagen = ImageDataGenerator(horizontal_flip=True, brightness_range=[0.5,1.5])
it_train = datagen.flow(X_train, y_train, batch_size=64)
steps = len(X_train)/64

# %% [markdown]
# # Soorten Layers

# %% [markdown]
# ![cnn-3.png](attachment:cnn-3.png)

# %% [markdown]
# ### - Rescaling Layers:
# In deze layer normaliseren we de input data, we doen dit door alle waardes te delen door de grootste waarde: 255. Dit zorgt er voor dat ons network sneller kan convergeren.
#
#
# ### - Convolutional Layers:
# Convolutional layers worden gebruikt als 'feature extractors'. In een convolutional layer slide een filter (een matrix van x bij y getallen die een patroon representeerd) over onze image bitmap met als doel een map te maken van waar het filterpatroon overeenkomt met een deel van onze image. Dit wordt gedaan door de getallen in het filter te vermenigvuldigen met de getallen van het deel van de de bitmap waar het filter op wordt toegepast en daar de som van te nemen, eventueel een bias er aan toe te voegen, en het in een activatie functie te stoppen.We gebruiken hier de non-lineaire activatiefunctie ReLu voor omdat onze data ook non-lineair is. Dit resultaat is dan één getal in de nieuwe feature map. Hoe vaak dit wordt gedaan is afhankelijk van de grootte van het filter, de grootte van de bitmap, en de strides variabele (de horizontale en verticale stapgrootte). De filters variabele geeft aan hoeveel van deze feature maps, met verschillende filters, worden gemaakt.
#
# Je kan zien dat na elke convolutional + pooling cycle het aantal filters verdubbeld wordt. Dit wordt zo gedaan omdat des te dieper je het netwerk in gaat des te complexer de patronen, en vooral de combinaties van patronen worden. Een van de eerdere convolutional layers kijkt dus bijvoorbeeld naar relatief simpele patronen zoals randen, maar de latere convolutional layers kunnen deze randen samenvoegen om meer complexere vormen te herkennen zoals een vleugel van een vliegtuig. Dit vergt natuurlijk redelijk veel computationele kracht en is dan ook een van de redenen om de volgende soort layers te gebruiken:
#
# ### - Pooling Layers:
# Waar in onze convolutional layer het filter willekeurig geïnitialiseerd werd werkt het bij pooling layers net even iets anders. Bij max pooling (de methode die ik gebruik) wordt er ook een filter toegepast op de bitmap maar dit filter neemt alleen het grootste getal op het toegepaste deel over naar de feature map. Het maakt in principe dus een soort samenvatting van de bitmap. Dit is een vorm van downsampling. Pooling layers leiden tot een enorme performance gain voor ons netwerk. Dit verminderen van je features kan ook helpen tegen overfitting.
#
# ### - Dense Layers:
# ### - Dropout Layers:

# %%
# deze parameters worden voor alle convolutional layers gebruikt
DefaultConv2D = partial(keras.layers.Conv2D,
 kernel_size=3, activation='relu', padding="same")


model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(32, 32, 3)),
    
    DefaultConv2D(filters = 32),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 32),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 32),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.2),
    
    DefaultConv2D(filters = 64),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 64),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 64),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.2),
    
    DefaultConv2D(filters = 128),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 128),
    tf.keras.layers.BatchNormalization(),
    DefaultConv2D(filters = 128),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation = 'relu', kernel_initializer = 'he_uniform'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation = 'softmax')
])

model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
              metrics = ['accuracy']
              
             )


early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                              patience=5)

history = model.fit(it_train,steps_per_epoch = steps ,epochs = 100,validation_data = (X_test,y_test), callbacks = [early_stop], batch_size = 64)
# Out:
# Epoch 1/100
# 781/781 [==============================] - 27s 32ms/step - loss: 2.0365 - accuracy: 0.3150 - val_loss: 1.4564 - val_accuracy: 0.4674
# Epoch 2/100
# 781/781 [==============================] - 25s 32ms/step - loss: 1.5222 - accuracy: 0.4518 - val_loss: 1.7259 - val_accuracy: 0.4407
# Epoch 3/100
# 781/781 [==============================] - 25s 32ms/step - loss: 1.3024 - accuracy: 0.5335 - val_loss: 1.1271 - val_accuracy: 0.5910
# Epoch 4/100
# 781/781 [==============================] - 25s 32ms/step - loss: 1.1625 - accuracy: 0.5804 - val_loss: 0.9477 - val_accuracy: 0.6625
# Epoch 5/100
# 781/781 [==============================] - 25s 32ms/step - loss: 1.0712 - accuracy: 0.6166 - val_loss: 0.9133 - val_accuracy: 0.6731
# Epoch 6/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.9918 - accuracy: 0.6475 - val_loss: 0.8411 - val_accuracy: 0.6992
# Epoch 7/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.9263 - accuracy: 0.6691 - val_loss: 0.8202 - val_accuracy: 0.7125
# Epoch 8/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.8857 - accuracy: 0.6881 - val_loss: 0.7599 - val_accuracy: 0.7355
# Epoch 9/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.8479 - accuracy: 0.7004 - val_loss: 0.8147 - val_accuracy: 0.7136
# Epoch 10/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.8149 - accuracy: 0.7140 - val_loss: 0.6904 - val_accuracy: 0.7556
# Epoch 11/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7864 - accuracy: 0.7230 - val_loss: 0.6775 - val_accuracy: 0.7626
# Epoch 12/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7601 - accuracy: 0.7341 - val_loss: 0.6652 - val_accuracy: 0.7657
# Epoch 13/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7404 - accuracy: 0.7382 - val_loss: 0.6946 - val_accuracy: 0.7560
# Epoch 14/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7214 - accuracy: 0.7463 - val_loss: 0.6340 - val_accuracy: 0.7747
# Epoch 15/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6985 - accuracy: 0.7525 - val_loss: 0.6061 - val_accuracy: 0.7895
# Epoch 16/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6767 - accuracy: 0.7624 - val_loss: 0.5981 - val_accuracy: 0.7937
# Epoch 17/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6623 - accuracy: 0.7696 - val_loss: 0.6474 - val_accuracy: 0.7768
# Epoch 18/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6474 - accuracy: 0.7723 - val_loss: 0.5531 - val_accuracy: 0.8106
# Epoch 19/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6303 - accuracy: 0.7799 - val_loss: 0.5532 - val_accuracy: 0.8128
# Epoch 20/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6184 - accuracy: 0.7840 - val_loss: 0.5688 - val_accuracy: 0.8027
# Epoch 21/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6061 - accuracy: 0.7884 - val_loss: 0.5454 - val_accuracy: 0.8092
# Epoch 22/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5889 - accuracy: 0.7931 - val_loss: 0.5606 - val_accuracy: 0.8028
# Epoch 23/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5819 - accuracy: 0.7956 - val_loss: 0.5273 - val_accuracy: 0.8199
# Epoch 24/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5632 - accuracy: 0.8038 - val_loss: 0.5684 - val_accuracy: 0.8067
# Epoch 25/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5556 - accuracy: 0.8067 - val_loss: 0.5457 - val_accuracy: 0.8105
# Epoch 26/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5506 - accuracy: 0.8076 - val_loss: 0.5716 - val_accuracy: 0.8028
# Epoch 27/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5412 - accuracy: 0.8106 - val_loss: 0.5032 - val_accuracy: 0.8273
# Epoch 28/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5256 - accuracy: 0.8173 - val_loss: 0.4994 - val_accuracy: 0.8310
# Epoch 29/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5166 - accuracy: 0.8196 - val_loss: 0.5409 - val_accuracy: 0.8172
# Epoch 30/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5156 - accuracy: 0.8206 - val_loss: 0.4869 - val_accuracy: 0.8321
# Epoch 31/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5035 - accuracy: 0.8241 - val_loss: 0.4755 - val_accuracy: 0.8379
# Epoch 32/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4927 - accuracy: 0.8289 - val_loss: 0.5383 - val_accuracy: 0.8173
# Epoch 33/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4874 - accuracy: 0.8294 - val_loss: 0.4825 - val_accuracy: 0.8354
# Epoch 34/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4793 - accuracy: 0.8330 - val_loss: 0.4691 - val_accuracy: 0.8399
# Epoch 35/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4739 - accuracy: 0.8343 - val_loss: 0.4759 - val_accuracy: 0.8383
# Epoch 36/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4665 - accuracy: 0.8361 - val_loss: 0.4715 - val_accuracy: 0.8367
# Epoch 37/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4615 - accuracy: 0.8385 - val_loss: 0.4602 - val_accuracy: 0.8424
# Epoch 38/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4535 - accuracy: 0.8419 - val_loss: 0.4604 - val_accuracy: 0.8435
# Epoch 39/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4471 - accuracy: 0.8440 - val_loss: 0.4411 - val_accuracy: 0.8524
# Epoch 40/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4447 - accuracy: 0.8459 - val_loss: 0.4406 - val_accuracy: 0.8508
# Epoch 41/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4395 - accuracy: 0.8466 - val_loss: 0.4477 - val_accuracy: 0.8471
# Epoch 42/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4352 - accuracy: 0.8476 - val_loss: 0.4301 - val_accuracy: 0.8555
# Epoch 43/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4278 - accuracy: 0.8496 - val_loss: 0.4429 - val_accuracy: 0.8523
# Epoch 44/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4182 - accuracy: 0.8545 - val_loss: 0.4376 - val_accuracy: 0.8528
# Epoch 45/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4129 - accuracy: 0.8560 - val_loss: 0.4389 - val_accuracy: 0.8530
# Epoch 46/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4077 - accuracy: 0.8563 - val_loss: 0.4831 - val_accuracy: 0.8392
# Epoch 47/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4027 - accuracy: 0.8588 - val_loss: 0.4303 - val_accuracy: 0.8557

# %%
def random_classification():
    index = random.randint(0,len(X_test)-1)
    prediction = model.predict(np.expand_dims(X_test[index], axis = 0))
    label = label_dict[np.argmax(y_test[index])]
    predicted_label = label_dict[np.argmax(prediction)]
    plt.imshow(X_test[index])
    plt.title(f"Real: {label} \nPrediction: {predicted_label}\n", color = 'green' if label == predicted_label else 'red')
    plt.show()

# %%
random_classification()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  batch_normalization_3 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_7 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_8 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_9 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_10 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 2,596,106
# Trainable params: 2,592,650
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
def plot_loss(history):
    
    plt.title('Cross Entropy Loss')
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
plot_loss(history)
